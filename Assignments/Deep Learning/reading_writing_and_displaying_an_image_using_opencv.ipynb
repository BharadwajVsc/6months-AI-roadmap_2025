# %% [markdown]
# # **OpenCV**

# %% [markdown]
# # Import necessary libraries

# %%
import cv2
import numpy as np

# %% [markdown]
# ## Loading the image

# %%
input=cv2.imread(r"C:\Users\bhara\Downloads\Pics\e224520bf63488fc66c81391b312fe80.jpg")#imread is used to read the image
input
# Out:
# array([[[ 22,  11,   3],
#         [ 22,  11,   3],
#         [ 22,  11,   3],
#         ...,
#         [ 27,  12,   3],
#         [ 27,  12,   3],
#         [ 27,  12,   3]],
#
#        [[ 24,  13,   5],
#         [ 24,  13,   5],
#         [ 24,  13,   5],
#         ...,
#         [ 32,  17,   8],
#         [ 32,  17,   8],
#         [ 32,  17,   8]],
#
#        [[ 24,  13,   5],
#         [ 24,  13,   5],
#         [ 24,  13,   5],
#         ...,
#         [ 30,  15,   6],
#         [ 30,  15,   6],
#         [ 30,  15,   6]],
#
#        ...,
#
#        [[ 74,  66,  59],
#         [ 74,  66,  59],
#         [ 74,  66,  59],
#         ...,
#         [ 99,  98, 100],
#         [ 99,  98, 100],
#         [ 99,  98, 100]],
#
#        [[ 79,  71,  64],
#         [ 79,  71,  64],
#         [ 79,  71,  64],
#         ...,
#         [ 99,  98, 100],
#         [ 99,  98, 100],
#         [ 99,  98, 100]],
#
#        [[ 63,  55,  48],
#         [ 63,  55,  48],
#         [ 63,  55,  48],
# ...

# %%
cv2.imshow('porsche',input)#imshow is used to display the image in a popup window
cv2.waitKey(0)#waitkey is used to hold the image
cv2.destroyAllWindows()#destroy all windows

# %% [markdown]
# ## Printing the height and width of the image

# %%
print(f'Height of the image is {input.shape[0]} pixels')
print(f'Width of the image is {input.shape[1]} pixels')
# Out:
# Height of the image is 474 pixels
# Width of the image is 842 pixels

# %%
cv2.imwrite('porsche1.jpg',input)#imwrite is used to save the image
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'd:\\fsds\\practice_codes\\deep_learning'
