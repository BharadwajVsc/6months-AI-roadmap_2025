# %%
first_name = 'bharadwaj'
last_name = 'velavalapalli'
country = 'japan'
city = 'kyoto'
age = 26
is_employeed = False
skills = ['Python', 'NextJS', 'JS']
personal_info = {
    'firstname':'Apashyampa', 
    'lastname':'Swami', 
    'country':'Sri Lanka',
    'city':'Colombo'
    }

print('First name:', first_name)
print('First name length:', len(first_name))
print('Last name: ', last_name)
print('Last name length: ', len(last_name))
print('Country: ', country)
print('City: ', city)
print('Age: ', age)
print('Employement Status: ', is_employeed)
print('Skills: ', skills)
print('Personal information: ', personal_info)
# Out:
# First name: bharadwaj
# First name length: 9
# Last name:  velavalapalli
# Last name length:  13
# Country:  india
# City:  hyderabad
# Age:  26
# Employement Status:  False
# Skills:  ['Python', 'NextJS', 'JS']
# Personal information:  {'firstname': 'Apashyampa', 'lastname': 'Swami', 'country': 'Sri Lanka', 'city': 'Colombo'}

# %%
first_name, last_name, country, age, is_employeed = 'bharadwaj', 'velavalapalli', 'kyoto', 1232, False
print(first_name, last_name, country, age, is_employeed)
print('First name:', first_name)
print('Last name: ', last_name)
print('Country: ', country)
print('Age: ', age)
print('Employement Status: ', is_employeed)
# Out:
# bharadwaj velavalapalli kyoto 1232 False
# First name: bharadwaj
# Last name:  velavalapalli
# Country:  kyoto
# Age:  1232
# Employement Status:  False
