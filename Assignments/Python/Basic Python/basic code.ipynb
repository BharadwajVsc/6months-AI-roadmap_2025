# %%
print(40 + 45.4)
# Out:
# 85.4

# %%
print(int(40 + 45.5))
# Out:
# 85

# %%
print(50 - 23)
print(23 - 42)
# Out:
# 27
# -19

# %%
print(-(23-34))
# Out:
# 11

# %%
print(23-45.7)
# Out:
# -22.700000000000003

# %%
print(int(23-45.7))
# Out:
# -22

# %%
print(23*34.45)
# Out:
# 792.35

# %%
print(int(23*34.45))
print(23**34.45)
# Out:
# 792
# 8.156877700688407e+46

# %%
print(float(45*56))
# Out:
# 2520.0

# %%
print(34/31)
# Out:
# 1.096774193548387

# %%
print(34//31)
# Out:
# 1

# %%
print(34%31)
# Out:
# 3

# %%
print(float(34%31))
# Out:
# 3.0

# %%
print(type(12))
print(type(123.34))
print(type(23+3j))
print(type("yokoso..."))
print(type([2,3,4,5,6,7,45,33,23,123]))
print(type({'name':'bharadwaj'}))
print(type({34,3}))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>
# <class 'set'>

# %%
print('yokoso, watashi no soul society ye!')
# Out:
# yokoso, watashi no soul society ye!

# %%
'yokoso, watashi no soul society ye!'
# Out:
# 'yokoso, watashi no soul society ye!'

# %%
print('welcome to aizen's soul society')
# Out:
#   Cell In[4], line 1
#     print('welcome to aizen's soul society')
#                                           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('welcome to aizen\'s soul society')
# Out:
# welcome to aizen's soul society

# %%
print('watashi'+ 'no soul society')
# Out:
# watashino soul society

# %%
print('watashi' + ' no soul society')
# Out:
# watashi no soul society

# %%
'yokoso ' * 5
# Out:
# 'yokoso yokoso yokoso yokoso yokoso '

# %%
print('watashi no\nsoul society')
# Out:
# watashi no
# soul society

# %%
print('yokoso,\nwatashi no\nsoul society')
# Out:
# yokoso,
# watashi no
# soul society

# %%
x=10
x
# Out:
# 10

# %%
x+12
# Out:
# 22

# %%
y=13
y
# Out:
# 13

# %%
x+y
# Out:
# 23

# %%
x
# Out:
# 10

# %%
x+12
# Out:
# 22

# %%
x
# Out:
# 10

# %%
_+x
# Out:
# 20

# %%
_+34
# Out:
# 54

# %%
name= 'bharadwaj'
name+' has bankai'
# Out:
# 'bharadwaj has bankai'

# %%
len(name)
# Out:
# 9

# %%
name[0]
# Out:
# 'b'

# %%
name[5]
# Out:
# 'd'

# %%
name[7]
# Out:
# 'a'

# %% [markdown]
# # Operators

# %% [markdown]
# # arithmetic operators

# %%
x1,y1=3,9
print(x1+y1)
# Out:
# 12

# %%
x1-y1
# Out:
# -6

# %%
x1*y1
# Out:
# 27

# %%
y1/x1
# Out:
# 3.0

# %%
y1//x1
# Out:
# 3

# %%
y1**x1
# Out:
# 729

# %%
y1%x1
# Out:
# 0

# %% [markdown]
# # assignment operators

# %%
x =2
x=x+2

# %%
x
# Out:
# 4

# %%
x+=2

# %%
x
# Out:
# 6

# %%
x+=2
x
# Out:
# 8

# %%
x+=2
x
# Out:
# 10

# %%
x+=2
x
# Out:
# 12

# %%
x-=2
x
# Out:
# 10

# %%
x-=2
x
# Out:
# 8

# %%
x-=2
x
# Out:
# 6

# %%
x*=2
x
# Out:
# 12

# %%
x*=2
x
# Out:
# 20

# %%
x*=2
x
# Out:
# 40

# %%
x*=2
x
# Out:
# 80

# %%
x/=2
x
# Out:
# 40.0

# %%
x/=2
x
# Out:
# 20.0

# %%
x/=2
x
# Out:
# 10.0

# %%
x//=2
x
# Out:
# 5.0

# %%
x//=2
x
# Out:
# 2.0

# %% [markdown]
# # unary operator

# %%
n=19
n
# Out:
# 19

# %%
m=-(n)
m
# Out:
# -19

# %% [markdown]
# # relational opreators

# %%
a=12
b=67
a==b
# Out:
# False

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a!=b
# Out:
# True

# %% [markdown]
# # logical operators

# %%
a>2 and b>100
# Out:
# False

# %%
a>2 or b>100
# Out:
# True

# %% [markdown]
# # number system conversion

# %%
bin(12)
# Out:
# '0b1100'

# %%
int('0b1100')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 int('0b1100')
#
# ValueError: invalid literal for int() with base 10: '0b1100'

# %%
int('0b1101',2)
# Out:
# 13

# %%
int(1100)
# Out:
# 1100

# %%
int(ob1100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 int(ob1100)
#
# NameError: name 'ob1100' is not defined

# %%
int(0b1100, 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 int(0b1100, 2)
#
# TypeError: int() can't convert non-string with explicit base

# %%
0b1100
# Out:
# 12

# %%
int(0b1101)
# Out:
# 13

# %%
oct(65)
# Out:
# '0o101'

# %%
int(0o101)
# Out:
# 65

# %%
hex(126)
# Out:
# '0x7e'

# %%
0zx7e
# Out:
#   Cell In[78], line 1
#     0zx7e
#     ^
# SyntaxError: invalid decimal literal

# %%
int(0x7e)
# Out:
# 126

# %% [markdown]
# # swapping variables

# %%
a=4
b=56

a=b
b=a
a,b
# Out:
# (56, 56)

# %%
a=4
b=56
a,b = b,a
print(a,b)
# Out:
# 56 4

# %%
a1=56
b1=86
temp = a1
a1=b1
b1=temp
print(a1,b1)
# Out:
# 86 56

# %%
a1 = a1 + b1
b1 = a1 - b1
a1 = a1 - b1
print(a1,b1)
# Out:
# 56 86

# %%
a1, b1 = b1, a1
print(a1, b1)
# Out:
# 86 56

# %% [markdown]
# # Bitwise Operators

# %% [markdown]
# #   compliment opearator

# %%
~19
# Out:
# -20

# %%
~192
# Out:
# -193

# %%
~~193
# Out:
# 193

# %%
~-193
# Out:
# 192

# %% [markdown]
# # bitwise '&', '|' and '^'

# %%
12 & 15
# Out:
# 12

# %%
12 & 25
# Out:
# 8

# %%
12 | 15
# Out:
# 15

# %%
12 | 25
# Out:
# 29

# %%
12 ^ 15
# Out:
# 3

# %%
12 ^ 25
# Out:
# 21

# %% [markdown]
# # bitwise right shift '>>' and left shift '<<'

# %%
20<<4
# Out:
# 320

# %%
12<<4
# Out:
# 192

# %%
10<<2
# Out:
# 40

# %%
10>>2
# Out:
# 2

# %%
20>>4
# Out:
# 1

# %%
20>>2
# Out:
# 5

# %% [markdown]
# # import math module

# %%
x = sqrt(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 x = sqrt(4)
#
# NameError: name 'sqrt' is not defined

# %%
import math
x = math.sqrt(4)
x
# Out:
# 2.0

# %%
x= math.cbrt(8)

# %%
x
# Out:
# 2.0

# %%
x= math.pow(2, 3)
x
# Out:
# 8.0

# %%
x = math.factorial(12)
x
# Out:
# 479001600

# %%
print(math.floor(12.34))    
print(math.ceil(12.34))
print(math.trunc(12.34))
print(math.fabs(-12.34))
# Out:
# 12
# 13
# 12
# 12.34

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(int(math.pi))
# Out:
# 3

# %%
from math import sqrt, pow, factorial, floor, ceil, trunc, fabs, pi
pow(2, 3)
# Out:
# 8.0

# %%
round(pow(2, 3))
# Out:
# 8

# %% [markdown]
# # user input function

# %%
a = input()
b = input()
c = a + b
print(c)
# Out:
# 245

# %%
a = input('Enter first number: ')
a1= int(a)
b = input('Enter second number: ')
b1 = int(b)
c=a1+b1
c
# Out:
# 7

# %%
a = int(input('Enter first number: '))
b = int(input('Enter second number: '))
c = a + b
print('The sum of', a, 'and', b, 'is', c)
# Out:
# The sum of 12 and 43 is 55

# %%
ch = input('Enter a character: ')
print(ch)
# Out:
# welcome to my world

# %%
print(ch[3])
# Out:
# c

# %%
ch = input('Enter a character: ')[1:5]
print(ch)
# Out:
# elco

# %%
a = float(input('Enter a number: '))
b = float(input('Enter another number: '))
c = a + b
print('the sum of', a, 'and', b, 'is', c)
# Out:
# the product of 1.1 and 3.6 is 4.7
