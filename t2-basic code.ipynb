# %%
print(40 + 45.4)
# Out:
# 85.4

# %%
print(int(40 + 45.5))
# Out:
# 85

# %%
print(50 - 23)
print(23 - 42)
# Out:
# 27
# -19

# %%
print(-(23-34))
# Out:
# 11

# %%
print(23-45.7)
# Out:
# -22.700000000000003

# %%
print(int(23-45.7))
# Out:
# -22

# %%
print(23*34.45)
# Out:
# 792.35

# %%
print(int(23*34.45))
print(23**34.45)
# Out:
# 792
# 8.156877700688407e+46

# %%
print(float(45*56))
# Out:
# 2520.0

# %%
print(34/31)
# Out:
# 1.096774193548387

# %%
print(34//31)
# Out:
# 1

# %%
print(34%31)
# Out:
# 3

# %%
print(float(34%31))
# Out:
# 3.0

# %%
print(type(12))
print(type(123.34))
print(type(23+3j))
print(type("yokoso..."))
print(type([2,3,4,5,6,7,45,33,23,123]))
print(type({'name':'bharadwaj'}))
print(type({34,3
